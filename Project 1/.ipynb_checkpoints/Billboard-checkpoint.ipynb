# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Data files
bb_path = "data/billboardHot100_1999-2019.csv"
songAtt_path = "data/songAttributes_1999-2019.csv"
gramAlb_path = "data/grammyAlbums_199-2019.csv"
roty_path = "data/ROTYdata (Edited) (1).csv"
aoty_path = "data/AOTYdata(Edited) (1).csv"


# Read the data
bb_data = pd.read_csv(bb_path)
songAtt_data = pd.read_csv(songAtt_path)
gramAlb_data = pd.read_csv(gramAlb_path)
roty_data = pd.read_csv(roty_path)
aoty_data = pd.read_csv(aoty_path)

# Combine the data into a single DataFrame
# results = pd.merge(mouse_metadata, study_results, on = "Mouse ID")
# bb_data.head()
# songAtt_data.head()
# gramAlb_data.head()
# Display the data table for preview

# %%
# rename merge column
bb_data = bb_data.rename(columns={'Artists': 'Artist'})
bb_data.head()
# Out:
#    Unnamed: 0                        Artist           Name  Weekly.rank  \
# 0           1                      Lil Nas,  Old Town Road            1
# 1           2  Shawn Mendes, Camila Cabello       Senorita            2
# 2           3                 Billie Eilish        Bad Guy            3
# 3           4                        Khalid           Talk            4
# 4           5     Ed Sheeran, Justin Bieber   I Don't Care            5
#
#    Peak.position  Weeks.on.chart        Week              Date  \
# 0            1.0             7.0  2019-07-06     April 5, 2019
# 1            NaN             NaN  2019-07-06     June 21, 2019
# 2            2.0            13.0  2019-07-06    March 29, 2019
# 3            3.0            20.0  2019-07-06  February 7, 2019
# 4            2.0             7.0  2019-07-06      May 10, 2019
#
#                                                Genre  \
# 0  Country,Atlanta,Alternative Country,Hip-Hop,Tr...
# 1                                                Pop
# 2  Hip-Hop,Dark Pop,House,Trap,Memes,Alternative ...
# 3                                      Synth-Pop,Pop
# 4                      Canada,UK,Dance,Dance-Pop,Pop
#
#                                      Writing.Credits  \
# 0  Jozzy, Atticus ross, Trent reznor, Billy ray c...
# 1  Cashmere cat, Jack patterson, Charli xcx, Benn...
# 2                             Billie eilish, Finneas
# 3              Howard lawrence, Guy lawrence, Khalid
# 4  Ed sheeran, Justin bieber, Shellback, Max mart...
#
#                                               Lyrics         Features
# 0  Old Town Road Remix \nOh, oh-oh\nOh\nYeah, I'm...  Billy Ray Cyrus
# 1  Senorita \nI love it when you call me senorita...              NaN
# 2  bad guy \nWhite shirt now red, my bloody nose\...              NaN
# 3  Talk \nCan we just talk? Can we just talk?\nTa...              NaN
# 4  I Don't Care \nI'm at a party I don't wanna be...              NaN

# %%
# take out unneccesary years
gramAlb_new = gramAlb_data[~gramAlb_data.GrammyYear.between(1999, 2009)]
gramAlb_new.columns = gramAlb_new.columns.str.strip()
gramAlb_new.head()
# Out:
#    Unnamed: 0                                 Award  GrammyYear  \
# 0           0                     Album Of The Year        2018
# 1           1      Best Traditional Pop Vocal Album        2018
# 2           2                  Best Pop Vocal Album        2018
# 3           3           Best Dance/Electronic Album        2018
# 4           4  Best Contemporary Instrumental Album        2018
#
#                              Genre            Album           Artist
# 0                          General      Golden Hour  Kacey Musgraves
# 1                  Traditional Pop           My Way    Willie Nelson
# 2                              Pop        Sweetener    Ariana Grande
# 3           Dance/Electronic Music  Woman Worldwide          Justice
# 4  Contemporary Instrumental Music  Steve Gadd Band  Steve Gadd Band

# %%
overallgenre = gramAlb_new["Genre"].value_counts()
genres = gramAlb_new["Genre"].unique()
plt.pie(overallgenre, labels = genres, autopct = "%1.2f%%", shadow = True, startangle = 0)
# Create axes which are equal so we have a perfect circle
plt.axis("equal")
# Save an image of our chart and print the final product to the screen
plt.savefig("PIECHART.png")
plt.show()

# %%
# filter
gramAlb_new2 = gramAlb_new.set_index("Award")
# gramAlb_new2.loc["Album Of The Year"]

# %%
# grammy 
gramAlb_new3 = gramAlb_new2.loc["Album Of The Year"].drop(columns = ["Unnamed: 0"])
gramAlb_new3.head(10)
# Out:
#                    GrammyYear    Genre                   Album  \
# Award
# Album Of The Year        2018  General             Golden Hour
# Album Of The Year        2017  General               24K Magic
# Album Of The Year        2016  General                      25
# Album Of The Year        2015  General                    1989
# Album Of The Year        2014  General           Morning Phase
# Album Of The Year        2013  General  Random Access Memories
# Album Of The Year        2012  General                   Babel
# Album Of The Year        2011  General                      21
# Album Of The Year        2010  General             The Suburbs
#
#                                                               Artist
# Award
# Album Of The Year                                    Kacey Musgraves
# Album Of The Year                                         Bruno Mars
# Album Of The Year                                              Adele
# Album Of The Year  ack Antonoff, Nathan Chapman, Imogen Heap, Max...
# Album Of The Year                                               Beck
# Album Of The Year                                          Daft Punk
# Album Of The Year                                     Mumford & Sons
# Album Of The Year                                              Adele
# Album Of The Year                                        Arcade Fire

# %%
# Create a clean DataFrame.
# df_2 = pd.merge(roty_data, aoty_data, on = "artist", how = "left")
# df_2.head(25)

# %%
roty_data.head()
# Out:
#    year                record           artist   status  \
# 0  2010          Need You Now  Lady Antebellum   Winner
# 1  2010  Empire State of Mind            Jay-Z  Nominee
# 2  2010              F*** You      CeeLo Green  Nominee
# 3  2010  Love the Way You Lie           Eminem  Nominee
# 4  2010        Nothin' on You            B.o.B  Nominee
#
#              Record Label   Did Perform at Grammys    Genre
# 0        Capital Nashville                    True  General
# 1               Roc Nation                   False  Hip-Hop
# 2       Warner Music Group                   False     Soul
# 3  Aftermath Entertainment                    True      Rap
# 4         Atlantic Records                    True  Pop Rap

# %%
roty_genre = roty_data["Genre"].value_counts()
genres = roty_data["Genre"].unique()
plt.pie(roty_genre, labels = genres, autopct = "%1.2f%%", shadow = True, startangle = 0)
# Create axes which are equal so we have a perfect circle
plt.axis("equal")
# Save an image of our chart and print the final product to the screen
plt.savefig("roty_genre.png")
plt.show()

# %%
# The majority of the Record of the Year Nominees and Winners from 2010-2019 are categorized as General, Hip-Hip, Soul, Rap and R&B, while the other 50% consist of the other genres.

# %%
#roty_data.head()
roty_winner = roty_data.set_index("status")
# roty_winner = roty_data.loc["Winner"]
roty_winner2 = roty_winner.loc["Winner"]
roty_winner2.head(25)
# Out:
#         year                            record            artist  \
# status
# Winner  2010                      Need You Now   Lady Antebellum
# Winner  2011               Rolling in the Deep             Adele
# Winner  2012      Somebody That I Used to Know             Gotye
# Winner  2013                         Get Lucky         Daft Punk
# Winner  2014  Stay with Me (Darkchild Version)         Sam Smith
# Winner  2015                       Uptown Funk       Mark Ronson
# Winner  2016                             Hello             Adele
# Winner  2017                         24K Magic        Bruno Mars
# Winner  2018                   This Is America  Childish Gambino
# Winner  2019                           Bad Guy     Billie Eilish
#
#                   Record Label   Did Perform at Grammys             Genre
# status
# Winner        Capital Nashville                    True           General
# Winner         Columbia Records                    True              Pop
# Winner  Eleven: A Music Company                   False  Alternative Rock
# Winner         Columbia Records                    True           General
# Winner          Capital Records                    True              Soul
# Winner              RCA Records                   False              Funk
# Winner         Columbia Records                    True              Soul
# Winner         Atlantic Records                    True              Funk
# Winner              RCA Records                   False           Hip-Hop
# Winner       Interscope Records                    True               Pop

# %%
winner_genre = roty_data["Genre"].value_counts()
roty_genre.plot.pie(autopct = "%1.1f%%")
plt.show()

# %%
aoty_genre.head()
#genres
# Out:
# Genre
# Pop        18
# R&B         8
# Hip-Hop     7
# Rock        6
# Rap         5
# Name: count, dtype: int64

# %%
aoty_genre = [18,8,7,6,5]
genres = ['Pop', 'R&B', 'Hip-Hop', 'Rock', 'Rap']
plt.pie(aoty_genre, labels = genres, autopct = "%1.2f%%")
# Create axes which are equal so we have a perfect circle
plt.axis("equal")
# Save an image of our chart and print the final product to the screen
plt.savefig("aoty_genre.png")
plt.show()

# %%
aoty_genre = aoty_data["Genre"].value_counts()
genres = ['Rock', 'Rap', 'Pop', 'General', 'R&B', 'Folk Rock', 'Country',
       'Soul', 'Hip-Hop', 'Funk', 'Experimental']
plt.pie(aoty_genre, labels = genres, autopct = "%1.2f%%")
# Create axes which are equal so we have a perfect circle
plt.axis("equal")
# Save an image of our chart and print the final product to the screen
plt.savefig("aoty_genre.png")
plt.show()

# %%
# Album of the Year Winners and Nominees consist largely almost one third of Pop Albums, collectively R&B, Hip-Hop, and Rock take another third of

# %%
df_2.dtypes
# Out:
# year_x                        int64
# record                       object
# artist                       object
# status_x                     object
# Record Label                 object
# Did Perform at Grammys_x       bool
# Genre_x                      object
# year_y                      float64
# album name                   object
# status_y                     object
# Record Label                 object
# Did Perform at Grammys_y     object
# Genre_y                      object
# dtype: object

# %%
# Create a clean DataFrame.
#df_3 = df_2.drop(columns = ["Writing.Credits", "Lyrics", "Features", "TimeSignature", "Valence", "Name_y", "Speechiness", "Unnamed: 0_y", "Unnamed: 0_x"])
#df_3.head(15)

# %%
# df_3.dtypes

# %%
#df_3[df_3.duplicated(keep=False)]

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM.
# Put into summry DF.

# %%
# Bar and Pie Charts
genrepie = df_2["Genre"].value_counts()
genrepie.plot.pie(autopct = "%1.1f%%")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Genre'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 2
#       1 # Bar and Pie Charts
# ----> 2 genrepie = df_2["Genre"].value_counts()
#       3 genrepie.plot.pie(autopct = "%1.1f%%")
#       4 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'Genre'

# %%
# Generate a box plot

# %%
# Generate a line plot

# %%
# Generate a scatter plot
